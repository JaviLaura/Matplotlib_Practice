# %% [markdown]
# <a href="https://colab.research.google.com/github/JaviLaura/Matplotlib_Practice/blob/main/Matplotlib_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Comment comment.

# %%
import matplotlib.pyplot as plt

# %%
randList = [1,2,3,4,5,6,7,8,3,2,3,4,2,1,2]
plt.plot(randList)

# %%
newList = [2,3,6,6,3,5,8,9,1,3,1,4,2,3,5]
plt.plot(newList,randList)

# %%
catList = ['female','male','other']
salList = [100000,90000,80000]
plt.bar(catList,salList)
# Out:
# <BarContainer object of 3 artists>

# %%
newDict = {'female':100000,'male':90000,'other':80000}
newDict.keys()
newDict.values()
plt.bar(newDict.keys(),newDict.values())
# Out:
# <BarContainer object of 3 artists>
